# %%
import pandas as pd
import numpy as np
from math import sqrt

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
df=pd.read_csv("House Price Prediction Dataset.csv")
df.isnull().sum()
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
x = df[['Area', 'Bedrooms', 'Bathrooms']]
y = df['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from math import sqrt
# Step 5: Create Logistic Regression Model
model = LinearRegression()

# Step 6: Train the model
model.fit(x_train, y_train)

# Step 7: Predict using test data
y_pred = model.predict(x_test)

print("\nMAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred), "\n")
# Out:
# MAE: 243756.4797682511
# MSE: 78440549944.81049
# RMSE: 280072.40125512274
# R2 Score: -0.008248471565956539

# %%
import joblib
joblib.dump(model,"housing.pkl")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in C:\Users\Eynir\anaconda3\Lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in C:\Users\Eynir\anaconda3\Lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in C:\Users\Eynir\anaconda3\Lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in C:\Users\Eynir\anaconda3\Lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in C:\Users\Eynir\anaconda3\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\Eynir\anaconda3\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in C:\Users\Eynir\anaconda3\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Eynir\anaconda3\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Eynir\anaconda3\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Eynir\anaconda3\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\Eynir\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Eynir\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Eynir\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Eynir\anaconda3\Lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Eynir\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Eynir\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\Eynir\anaconda3\Lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Eynir\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Eynir\anaconda3\Lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
