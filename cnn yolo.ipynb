# %%
import torch
import cv2
import matplotlib.pyplot as plt
import numpy as np

from ultralytics import YOLO
from torchvision import transforms
from PIL import Image

# %%
yolo_model = YOLO('yolov8n.pt')

# %%
result = yolo_model(r"C:\Users\Eynir\OneDrive\Pictures\images.jpg")

# Show the first result
result[0].show()
# Out:
# image 1/1 C:\Users\Eynir\OneDrive\Pictures\images.jpg: 640x448 8 persons, 1 bottle, 4 wine glasss, 2 cups, 1 dining table, 264.4ms
# Speed: 15.7ms preprocess, 264.4ms inference, 21.5ms postprocess per image at shape (1, 3, 640, 448)

# %%
result[0].save(filename="yolo_output.jpg")

# Read the saved image with OpenCV
img = cv2.imread("yolo_output.jpg")

# Plot with matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("Detection")
plt.show()
